# %%
import requests

url = "http://127.0.0.1:8000/logs-db/"
data = {'theme': 'Компьютерное зрение',
  'question': 'Какие архитектуры нейронных сетей чаще всего используются для решения задач классификации изображений в компьютерном зрении, и почему они эффективны? В ответе укажите конкретные примеры архитектур и объясните их преимущества. ',
  'answer': '"на данный момент чаще всего используются либо сверточные сети либо картиночные трансформеры изначально это был алекс нет впоследствии это от гугла инсепшн нет всякие сети с остаточными связями резнет и так далее"\n',
  'comment': 'Ответ пользователя поверхностно освещает тему архитектур нейронных сетей для классификации изображений. Он упоминает несколько популярных архитектур таких как AlexNet InceptionNet и ResNet но не объясняет почему они эффективны или каким образом они решают специфические проблемы классификации изображений. Например не рассмотрены аспекты такие как способность сверточных сетей обрабатывать пространственные структуры данных или различия между свертоками и вниманием в трансформерах. Также не указано как эти архитектуры адаптируются к современным вычислительным ограничениям и требованиям к производительности. ',
  'mark': 6,
  'userID': 5, 'start_time': '2025-03-16T10:10:48.601Z'}


response = requests.patch(url, json=data)

response.content.decode("utf-8")
# Out:
# '{"response":"QA block {\'theme\': \'Компьютерное зрение\', \'question\': \'Какие архитектуры нейронных сетей чаще всего используются для решения задач классификации изображений в компьютерном зрении, и почему они эффективны? В ответе укажите конкретные примеры архитектур и объясните их преимущества. \', \'answer\': \'\\"на данный момент чаще всего используются либо сверточные сети либо картиночные трансформеры изначально это был алекс нет впоследствии это от гугла инсепшн нет всякие сети с остаточными связями резнет и так далее\\"\\\\n\', \'comment\': \'Ответ пользователя поверхностно освещает тему архитектур нейронных сетей для классификации изображений. Он упоминает несколько популярных архитектур таких как AlexNet InceptionNet и ResNet но не объясняет почему они эффективны или каким образом они решают специфические проблемы классификации изображений. Например не рассмотрены аспекты такие как способность сверточных сетей обрабатывать пространственные структуры данных или различия 
# ...
