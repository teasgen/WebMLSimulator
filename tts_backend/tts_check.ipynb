# %%
import gigaam
model_name = "ctc"
audio_path = "/Users/teasgen/workspace/diploma/main_backend/temp_audio.wav"

model = gigaam.load_model(model_name)
transcription = model.transcribe(audio_path)
# Out:
# /Users/teasgen/workspace/diploma/GigaAM/gigaam/__init__.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location="cpu")
# WARNING:root:fp16 is not supported on CPU. Leaving fp32 weights...
# /Users/teasgen/workspace/diploma/GigaAM/gigaam/preprocess.py:40: UserWarning: The given buffer is not writable, and PyTorch does not support non-writable tensors. This means you can write to the underlying (supposedly non-writable) buffer using the tensor. You may want to copy the buffer to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:1566.)
#   return torch.frombuffer(audio, dtype=torch.int16).float() / 32768.0

# %%
transcription = model.transcribe(audio_path)

# %%
import gigaam

model = gigaam.load_model("ctc")
recognition_result = model.transcribe_longform(audio_path)

for utterance in recognition_result:
   transcription = utterance["transcription"]
   start, end = utterance["boundaries"]
   print(f"[{gigaam.format_time(start)} - {gigaam.format_time(end)}]: {transcription}")
# Out:
# /Users/teasgen/workspace/diploma/GigaAM/gigaam/__init__.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location="cpu")
# WARNING:root:fp16 is not supported on CPU. Leaving fp32 weights...
# [00:00:00 - 00:05:33]: раз два три четыре пять

# %%
from pydub import AudioSegment

AudioSegment.from_file(audio_path, format="wav")
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
from pydub import AudioSegment
import requests

with open(audio_path, "rb") as audio_file:
    response = requests.post(
        url="http://localhost:3001/transcribe/",
        files={"audio": audio_file}
    )

# %%
response.__dict__
# Out:
# {'_content': b'{"transcriptions":["\xd1\x80\xd0\xb0\xd0\xb7 \xd0\xb4\xd0\xb2\xd0\xb0 \xd1\x82\xd1\x80\xd0\xb8 \xd1\x87\xd0\xb5\xd1\x82\xd1\x8b\xd1\x80\xd0\xb5 \xd0\xbf\xd1\x8f\xd1\x82\xd1\x8c"]}',
#  '_content_consumed': True,
#  '_next': None,
#  'status_code': 200,
#  'headers': {'Date': 'Sun, 23 Feb 2025 11:21:42 GMT', 'Server': 'WSGIServer/0.2 CPython/3.10.15', 'Content-Type': 'application/json', 'Vary': 'Accept, Cookie', 'Allow': 'POST, OPTIONS', 'X-Frame-Options': 'DENY', 'Content-Length': '65', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'same-origin', 'Cross-Origin-Opener-Policy': 'same-origin'},
#  'raw': <urllib3.response.HTTPResponse at 0x3780ffc40>,
#  'url': 'http://localhost:3001/transcribe/',
#  'encoding': 'utf-8',
#  'history': [],
#  'reason': 'OK',
#  'cookies': <RequestsCookieJar[]>,
#  'elapsed': datetime.timedelta(microseconds=542978),
#  'request': <PreparedRequest [POST]>,
#  'connection': <requests.adapters.HTTPAdapter at 0x3780ffb20>}
